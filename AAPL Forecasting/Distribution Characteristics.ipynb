# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# load data
df = pd.read_csv("AAPL_clean.csv")

# parsing & sorting
df['ds'] = pd.to_datetime(df['ds'])
df = df.sort_values('ds')

# ====== DISTRIBUTION ======
skewness = df['y'].skew()
kurtosis = df['y'].kurtosis()

# ====== OUTPUT ======
print("Skewness:", skewness)
print("Kurtosis:", kurtosis)
# Out:
# Skewness: 0.2623594257924092
# Kurtosis: -1.201800960904872
