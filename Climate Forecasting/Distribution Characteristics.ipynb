# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# load data
df = pd.read_csv("climate_jakarta_96745.csv")

# parsing & sorting
df['ds'] = pd.to_datetime(df['ds'])
df = df.sort_values('ds')

# ====== DISTRIBUTION ======
skewness = df['y'].skew()
kurtosis = df['y'].kurtosis()

# ====== OUTPUT ======
print("Skewness:", skewness)
print("Kurtosis:", kurtosis)
# Out:
# Skewness: -0.6465308143977038
# Kurtosis: 0.9354657670978783
